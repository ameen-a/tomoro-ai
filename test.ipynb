# %%
import os

def list_files(startpath):
    output = []
    for root, dirs, files in os.walk(startpath):
        level = root.replace(startpath, '').count(os.sep)
        indent = ' ' * 4 * level + '- '
        output.append(f"{indent}{os.path.basename(root)}/")
        sub_indent = ' ' * 4 * (level + 1) + '- '
        for f in files:
            output.append(f"{sub_indent}{f}")
    return '\n'.join(output)

# Usage
print(list_files('.'))
# Out:
# - ./
#     - structure.md
#     - .DS_Store
#     - requirements.txt
#     - README.md
#     - .gitignore
#     - .env
#     - .gitattributes
#     - test.ipynb
#     - tests/
#     - scripts/
#     - report/
#     - .git/
#         - config
#         - HEAD
#         - description
#         - index
#         - COMMIT_EDITMSG
#         - objects/
#             - a4/
#                 - 23efc089510c75456d4261a8a8437d78f48fb3
#             - df/
#                 - e0770424b2a19faf507a501ebfc23be8f54e7b
#             - pack/
#             - info/
#             - 90/
#                 - 00fc2c4c52a79666114daf5560325e17f96501
#             - c3/
#                 - 536d42d48cd0ace30dbe4045570fa9efeaa1d8
#         - info/
#             - exclude
#         - logs/
#             - HEAD
#             - refs/
#                 - heads/
#                     - main
#         - hooks/
#             - commit-msg.sample
#             - pre-rebase.sample
#             - sendemail-validate.sample
#             - pre-commit.sample
#             - applypatch-msg.sample
#             - fsmonitor-watchman.sample
#             - pre-receive.sample
#             - prepare-commit-msg.sample
#             - post-update.sample
#             - pre-merge-commit.sample
#             - pre-applypatch.sample
#             - pre-push.sample
#             - update.sample
#             - push-to-checkout.sample
#         - refs/
#             - heads/
#                 - main
#             - tags/
#         - branches/
#     - data/
#         - .DS_Store
#         - results/
#         - processed/
#         - raw/
#             - train.json
#     - src/
#         - .DS_Store
#         - config.py
#         - utils/
#         - models/
#             - openai.py
#             - anthropic.py
#             - base.py
#         - reasoning/
#             - parser.py
#             - evaluator.py
#             - executor.py
#         - prompts/
#             - templates.py
#         - evaluation/
#             - metrics.py
#             - visualiser.py
#             - answer_extractor.py
#         - data/
#             - preprocessor.py
#             - loader.py
#         - wandb/
#             - wand_logger.py
#             - tracker.py

# %%
import os

def list_files(startpath):
    output = []
    for root, dirs, files in os.walk(startpath):
        level = root.replace(startpath, '').count(os.sep)
        indent = ' ' * 4 * level + '- '
        output.append(f"{indent}{os.path.basename(root)}/")
        sub_indent = ' ' * 4 * (level + 1) + '- '
        for f in files:
            output.append(f"{sub_indent}{f}")
    return '\n'.join(output)

# Usage
print(list_files('/path/to/your/directory'))
